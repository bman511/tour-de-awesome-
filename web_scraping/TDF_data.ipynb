# %%
import requests
import html5lib
import pandas as pd
from bs4 import BeautifulSoup
import os
import json
import numpy as np
import datetime
from config import user, pwd

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# This is the base URL to get links to unstyled pages with the tables of data
base_url = "https://www.letour.fr"
# The DOM codes the results as such
tab_dict = {'ite':'Stage',
'itg':'General Classification'}
# Or for easy iterating.
short_list = ['ite','itg']

# %%
# # stages = np.arange(1,2) #We can change the range to 1,22 to get all 21 stages. Testing 1 for now.
# stages = [6]

# %%
# This cell scrapes the page for stage 1 and extracts a list of raw URLs coded with the classification code
# Scraping with requests and Beautiful Soup for the correct div.

def scrape_pages(stage_id):
    stage_id = stage_id
    links_list = []
 
    start_url = f"{base_url}/en/rankings/stage-{stage_id}" #URL to stage)
    print(f"Getting result links for {start_url}")
    
    page = requests.get(start_url)

    if page.status_code == 200:
        content = page.content
        soup = BeautifulSoup(content, "html5lib")

    #Pull out a specific block of code with two sets of coded URLs from the soup.
        try:
            all_links = soup.find_all(class_="tabs__link js-tabs-ranking")
            links_list.append(all_links)
        except ElementDoesNotExist as e:
            print(f"That does not appear to be a valid results URL. {e}")

    # Parsing out the list of json-ish links from the DOM into a dictionary of functional URLs

    url_dict = {}

    for item in all_links:
        myurl = item['data-ajax-stack']
        #clean up the code into a useable URL
        myurl = myurl.replace('\/', '/')
        myurls = json.loads(myurl)
        for key, value in myurls.items():
            url_dict[key] = f"{base_url}{value}"

    # TODO loop through each stage and get the results. For now just look at a single stage, not any more or other results

    for key, value in url_dict.items():
        
        try:
            if key == 'ite':
                print(f"Getting results from {value}")
                get_results(value, 1, stage_id)
            elif key == 'itg':
                print(f"Getting results from {value}")
                get_results(value, 2, stage_id)
        except ValueError:
            print(f"Error getting results from {value}")
            pass

# %%
# Go to the link parsed out of the DOM and it is a plain URL page with a single, nested table
# table_list = [] #Not used here, we will have to append the data to a list or do a direct load to SQL database from here

def get_results(myurl, race_result_type_id, stage_id):

    try:
        table = pd.read_html(myurl)
        df = table[0]
        print(f"Table scraped for stage {stage_id}")
    except KeyError:
        print(f"Error with stage {stage_id}")
        pass
# put foreign keys into dataframe before insert into mySql

    df["stage_id"] = stage_id
    df["race_result_type_id"] = race_result_type_id
    # Reformat the times
    df['Result'] = df['Times'].str.replace('h ', ':').str.replace('\'\'', '').str.replace('\' ',':')
# Calculate bonus/penalty in seconds
    for index, row in df.iterrows():
        if 'B' in row['B']:
            bonus = row['B']
            bonus= bonus.split(' : ')[1].replace("''",'')
            df.loc[index, 'rider_bonus'] = bonus
        elif 'P' in row['P']:
            bonus = row['P']
            seconds = bonus.replace('P : ','').replace("'",'').split(' ')[1]
            minutes = int(bonus.replace('P : ','').replace("'",'').split(' ')[0])*60
            bonus = minutes + int(seconds)
            df.loc[index, 'rider_bonus'] = int(bonus * -1)

# Calculate time in seconds
    for index, row in df.iterrows():
        if ':' in row['Result']:
            t = row['Result']
            h,m,s = t.split(':')
            df.loc[index, 'rider_time'] = int(datetime.timedelta(hours=int(h),minutes=int(m),seconds=int(s)).total_seconds())

# Remove extra columns
    df = df.drop(['Rider','Team','Gap', 'B', 'P','Times','Result'], axis=1)
# Rename columns to match
    df = df.rename({'Rank': 'ranking', 'Rider No.': 'rider_id'}, axis='columns')
    engine = create_engine(f"mysql://{user}:{pwd}@localhost/letour_db")
    df.to_sql(name='race_results',con=engine,if_exists='append', index=False)

# %%
stages = np.arange(1,22)
# The result of this call will be pushed to the database
for i in stages:
    scrape_pages(i)
# Out:
# Getting result links for https://www.letour.fr/en/rankings/stage-1
# Getting results from https://www.letour.fr/en/ajax/ranking/1/itg/bd845dfbbdf0630f11da790f0cad3096/none
# Table scraped for stage 1
# Getting results from https://www.letour.fr/en/ajax/ranking/1/ite/72d3750b88cc75c1e386e3a8f55a9d96/none
# Table scraped for stage 1
# Getting result links for https://www.letour.fr/en/rankings/stage-2
# Getting results from https://www.letour.fr/en/ajax/ranking/2/itg/fca07fb6b35baa3d6dfe2d4500ea91ed/none
# Table scraped for stage 2
# Getting results from https://www.letour.fr/en/ajax/ranking/2/ite/6f21d73eddddbb74e35c0113a43935ca/none
# Table scraped for stage 2
# Getting result links for https://www.letour.fr/en/rankings/stage-3
# Getting results from https://www.letour.fr/en/ajax/ranking/3/itg/8cc975d0be03e5d50e78530e0a4b6f7d/none
# Table scraped for stage 3
# Getting results from https://www.letour.fr/en/ajax/ranking/3/ite/77864547454b8433e7ab54f08c7c64d0/none
# Error getting results from https://www.letour.fr/en/ajax/ranking/3/ite/77864547454b8433e7ab54f08c7c64d0/none
# Getting result links for https://www.letour.fr/en/rankings/stage-4
# Getting results from https://www.letour.fr/en/ajax/ranking/4/itg/cc999318dde14c5d0f598e0df7812039/none
# Table scraped for stage 4
# Getting results from https://www.letour.fr/en/ajax/ranking/4/ite/87cf72c99ffbe2a64fca96d9a741437a/none
# Table scraped for stage 4
# Getting result links for https://www.letour.fr/en/rankings/stage-5
# Getting results from https://www.letour.fr/en/ajax/ranking/5/itg/eeaeb81976edd50706d39f07cf2621c8/none
# Table scraped for stage 5
# Getting results from https://www.letour.fr/en/ajax/ranking/5/ite/3fa25e49c38fd588af3bd8393877beb0/none
# Table scraped for stage 5
# Getting result links for https://www.letour.fr/en/rankings/stage-6
# Getting results from https://www.letour.fr/en/ajax/ranking/6/itg/2e6b59402b30aa758dec803853e707e4/none
# Table scraped for stage 6
# Getting results from https://www.letour.fr/en/ajax/ranking/6/ite/b39465825894e28f8da03d6bc738619d/none
# Table scraped for stage 6
# Getting result links for https://www.letour.fr/en/rankings/stage-7
# Getting results from https://www.letour.fr/en/ajax/ranking/7/itg/a7d677cfcfd6a3b14e0c66f610c43fa6/none
# Table scraped for stage 7
# Getting results from https://www.letour.fr/en/ajax/ranking/7/ite/36fc3ca66cb201d14291938551a1ab14/none
# Table scraped for stage 7
# Getting result links for https://www.letour.fr/en/rankings/stage-8
# Getting results from https://www.letour.fr/en/ajax/ranking/8/itg/8f50a246e3afec345b8887512ae15315/none
# Table scraped for stage 8
# Getting results from https://www.letour.fr/en/ajax/ranking/8/ite/b7df59eede3f553b282214f0e96673a6/none
# Table scraped for stage 8
# Getting result links for https://www.letour.fr/en/rankings/stage-9
# Getting results from https://www.letour.fr/en/ajax/ranking/9/itg/28fa69f3142682c278a212cf59d646c7/none
# Table scraped for stage 9
# Getting results from https://www.letour.fr/en/ajax/ranking/9/ite/01fb010bb6faab3c7e43dfdb070e396d/none
# Table scraped for stage 9
# Getting result links for https://www.letour.fr/en/rankings/stage-10
# Getting results from https://www.letour.fr/en/ajax/ranking/10/itg/cdfb0b3fae730ef4159c790e9639ed93/none
# Table scraped for stage 10
# Getting results from https://www.letour.fr/en/ajax/ranking/10/ite/f9ed1f03a96333fd6c58dd800993202f/none
# Table scraped for stage 10
# Getting result links for https://www.letour.fr/en/rankings/stage-11
# Getting results from https://www.letour.fr/en/ajax/ranking/11/itg/1ca40caf4762ca8656de7a752d7c5f42/none
# Table scraped for stage 11
# Getting results from https://www.letour.fr/en/ajax/ranking/11/ite/add6d6ad3fb0c6fa88ff70d28eb4912c/none
# Table scraped for stage 11
# Getting result links for https://www.letour.fr/en/rankings/stage-12
# Getting results from https://www.letour.fr/en/ajax/ranking/12/itg/e84cb71ba4a0da910cf6e5ff0edb0736/none
# Table scraped for stage 12
# Getting results from https://www.letour.fr/en/ajax/ranking/12/ite/751aa03ca30ba4762306160a9d2284f8/none
# Table scraped for stage 12
# Getting result links for https://www.letour.fr/en/rankings/stage-13
# Getting results from https://www.letour.fr/en/ajax/ranking/13/itg/8532e10a8f49261c752759b02dc5d296/none
# Table scraped for stage 13
# Getting results from https://www.letour.fr/en/ajax/ranking/13/ite/052d7cae8af6baf8c2ea24b9d3a6f121/none
# Table scraped for stage 13
# Getting result links for https://www.letour.fr/en/rankings/stage-14
# Getting results from https://www.letour.fr/en/ajax/ranking/14/itg/2e61b42487d3820b311c76e763bf39e4/none
# Table scraped for stage 14
# Getting results from https://www.letour.fr/en/ajax/ranking/14/ite/bb783432bae3c3b59e888f18f2748637/none
# Table scraped for stage 14
# Getting result links for https://www.letour.fr/en/rankings/stage-15
# Getting results from https://www.letour.fr/en/ajax/ranking/15/itg/093f816162aa3ea3f7b2f7e1f58d6f19/none
# Table scraped for stage 15
# Getting results from https://www.letour.fr/en/ajax/ranking/15/ite/60f26a8cb35b113a1ad8c660144e814f/none
# Table scraped for stage 15
# Getting result links for https://www.letour.fr/en/rankings/stage-16
# Getting results from https://www.letour.fr/en/ajax/ranking/16/itg/6767775ba25e0c8f39de7612c3e94d99/none
# Table scraped for stage 16
# Getting results from https://www.letour.fr/en/ajax/ranking/16/ite/a5db26e03f62ec10a567984339e85a8b/none
# Table scraped for stage 16
# Getting result links for https://www.letour.fr/en/rankings/stage-17
# Getting results from https://www.letour.fr/en/ajax/ranking/17/itg/adafc7ca95472d06cdd5ef81abc24084/none
# Table scraped for stage 17
# Getting results from https://www.letour.fr/en/ajax/ranking/17/ite/fc7361407c70412cb08eb70948b47756/none
# Table scraped for stage 17
# Getting result links for https://www.letour.fr/en/rankings/stage-18
# Getting results from https://www.letour.fr/en/ajax/ranking/18/itg/26077b79a64815925288cd4a64e62cb6/none
# Table scraped for stage 18
# Getting results from https://www.letour.fr/en/ajax/ranking/18/ite/7bfed2b44b06f426c96f0ebd67dd5586/none
# Table scraped for stage 18
# Getting result links for https://www.letour.fr/en/rankings/stage-19
# Getting results from https://www.letour.fr/en/ajax/ranking/19/itg/18f11c81b4cd83f7b82b47a88d939a9c/none
# Table scraped for stage 19
# Getting results from https://www.letour.fr/en/ajax/ranking/19/ite/8e095350585b7868e90c24e92f0e9694/none
# Table scraped for stage 19
# Getting result links for https://www.letour.fr/en/rankings/stage-20
# Getting results from https://www.letour.fr/en/ajax/ranking/20/itg/f0a38aa7e50e98d1e4374c175faa8cb6/none
# Table scraped for stage 20
# Getting results from https://www.letour.fr/en/ajax/ranking/20/ite/75b54491d06887ea121cfe2f484a725d/none
# Table scraped for stage 20
# Getting result links for https://www.letour.fr/en/rankings/stage-21
# Getting results from https://www.letour.fr/en/ajax/ranking/21/itg/bdac3b5ec7a3ff5eb6ce88fe7bce60d2/none
# Table scraped for stage 21
# Getting results from https://www.letour.fr/en/ajax/ranking/21/ite/e4c7e8d394cc69def470115fdad0b79d/none
# Table scraped for stage 21

# %%
engine = create_engine(f"mysql://{user}:{pwd}@localhost/letour_db")
data = engine.execute("SELECT * FROM race_results")

for record in data:
    print(record)
# Out:
# (1, 6, 2, 1, 87, '81346', '2', None)
# (2, 6, 2, 2, 8, '81349', '3', None)
# (3, 6, 2, 3, 88, '81351', None, None)
# (4, 6, 2, 4, 101, '81352', '3', None)
# (5, 6, 2, 5, 104, '81358', '6', None)
# (6, 6, 2, 6, 105, '81364', None, None)
# (7, 6, 2, 7, 11, '81391', None, None)
# (8, 6, 2, 8, 78, '81397', '4', None)
# (9, 6, 2, 9, 114, '81398', None, None)
# (10, 6, 2, 10, 121, '81399', None, None)
# (11, 6, 2, 11, 81, '81399', None, None)
# (12, 6, 2, 12, 75, '81401', None, None)
# (13, 6, 2, 13, 61, '81408', None, None)
# (14, 6, 2, 14, 1, '81408', None, None)
# (15, 6, 2, 15, 36, '81409', None, None)
# (16, 6, 2, 16, 51, '81414', None, None)
# (17, 6, 2, 17, 166, '81423', None, None)
# (18, 6, 2, 18, 191, '81424', None, None)
# (19, 6, 2, 19, 32, '81429', '-20', None)
# (20, 6, 2, 20, 161, '81432', None, None)
# (21, 6, 2, 21, 91, '81433', '10', None)
# (22, 6, 2, 22, 2, '81436', None, None)
# (23, 6, 2, 23, 21, '81451', None, None)
# (24, 6, 2, 24, 41, '81463', None, None)
# (25, 6, 2, 25, 141, '81468', None, None)
# (26, 6, 2, 26, 58, '81474', None, None)
# (27, 6, 2, 27, 71, '81476', None, None)
# (28, 6, 2, 28, 16, '81479', None, None)
# (29, 6, 2, 29, 55, '81488', None, None)
# (30, 6, 2, 30, 68, '81499', None, None)
# (31, 6, 2, 31, 111, '81512', '32', None)
# (32, 6, 2, 32, 158, '81524', None, None)
# (33, 6, 2, 33, 26, '81546', '6', None)
# (34, 6, 2, 34, 42, '81562', None, None)
# (35, 6, 2, 35, 28, '81568', None, None)
# (36, 6, 2, 36, 134, '81581', None, None)
# (37, 6, 2, 37, 83, '81583', None, None)
# (38, 6, 2, 38, 183, '81588', '3', None)
# (39, 6, 2, 39, 126, '81589', None, None)
# (40, 6, 2, 40, 207, '81593', None, None)
# (41, 6, 2, 41, 216, '81602', None, None)
# (42, 6, 2, 42, 181, '81607', '1', None)
# (43, 6, 2, 43, 44, '81630', None, None)
# (44, 6, 2, 44, 132, '81641', None, None)
# (45, 6, 2, 45, 24, '81646', None, None)
# (46, 6, 2, 46, 211, '81655', None, None)
# (47, 6, 2, 47, 34, '81690', None, None)
# (48, 6, 2, 48, 52, '81696', '12', None)
# (49, 6, 2, 49, 122, '81705', None, None)
# (50, 6, 2, 50, 125, '81705', None, None)
# (51, 6, 2, 51, 67, '81709', None, None)
# (52, 6, 2, 52, 93, '81718', None, None)
# (53, 6, 2, 53, 96, '81733', None, None)
# (54, 6, 2, 54, 116, '81738', None, None)
# (55, 6, 2, 55, 182, '81741', None, None)
# (56, 6, 2, 56, 46, '81764', None, None)
# (57, 6, 2, 57, 152, '81795', None, None)
# (58, 6, 2, 58, 188, '81815', None, None)
# (59, 6, 2, 59, 156, '81819', None, None)
# (60, 6, 2, 60, 113, '81825', None, None)
# (61, 6, 2, 61, 212, '81825', None, None)
# (62, 6, 2, 62, 175, '81828', None, None)
# (63, 6, 2, 63, 214, '81839', None, None)
# (64, 6, 2, 64, 54, '81851', None, None)
# (65, 6, 2, 65, 136, '81866', None, None)
# (66, 6, 2, 66, 192, '81874', None, None)
# (67, 6, 2, 67, 165, '81880', None, None)
# (68, 6, 2, 68, 35, '81892', None, None)
# (69, 6, 2, 69, 85, '81906', None, None)
# (70, 6, 2, 70, 4, '81927', None, None)
# (71, 6, 2, 71, 76, '81928', None, None)
# (72, 6, 2, 72, 27, '81961', '1', None)
# (73, 6, 2, 73, 115, '81961', None, None)
# (74, 6, 2, 74, 14, '81971', None, None)
# (75, 6, 2, 75, 62, '82009', '3', None)
# (76, 6, 2, 76, 195, '82013', None, None)
# (77, 6, 2, 77, 18, '82017', None, None)
# (78, 6, 2, 78, 187, '82025', None, None)
# (79, 6, 2, 79, 133, '82031', None, None)
# (80, 6, 2, 80, 198, '82034', None, None)
# (81, 6, 2, 81, 215, '82050', '2', None)
# (82, 6, 2, 82, 77, '82058', None, None)
# (83, 6, 2, 83, 145, '82084', None, None)
# (84, 6, 2, 84, 57, '82101', None, None)
# (85, 6, 2, 85, 47, '82105', None, None)
# (86, 6, 2, 86, 5, '82105', None, None)
# (87, 6, 2, 87, 178, '82115', None, None)
# (88, 6, 2, 88, 33, '82123', None, None)
# (89, 6, 2, 89, 25, '82151', None, None)
# (90, 6, 2, 90, 204, '82153', None, None)
# (91, 6, 2, 91, 217, '82157', None, None)
# (92, 6, 2, 92, 184, '82168', '3', None)
# (93, 6, 2, 93, 12, '82170', None, None)
# (94, 6, 2, 94, 147, '82171', None, None)
# (95, 6, 2, 95, 146, '82192', None, None)
# (96, 6, 2, 96, 72, '82197', None, None)
# (97, 6, 2, 97, 92, '82251', None, None)
# (98, 6, 2, 98, 193, '82279', None, None)
# (99, 6, 2, 99, 117, '82279', None, None)
# (100, 6, 2, 100, 56, '82289', None, None)
# (101, 6, 2, 101, 194, '82291', None, None)
# (102, 6, 2, 102, 155, '82307', None, None)
# (103, 6, 2, 103, 118, '82316', None, None)
# (104, 6, 2, 104, 37, '82319', None, None)
# (105, 6, 2, 105, 168, '82358', None, None)
# (106, 6, 2, 106, 43, '82372', None, None)
# (107, 6, 2, 107, 176, '82387', '1', None)
# (108, 6, 2, 108, 95, '82400', None, None)
# (109, 6, 2, 109, 162, '82406', None, None)
# (110, 6, 2, 110, 48, '82408', None, None)
# (111, 6, 2, 111, 154, '82451', None, None)
# (112, 6, 2, 112, 108, '82484', None, None)
# (113, 6, 2, 113, 38, '82510', None, None)
# (114, 6, 2, 114, 6, '82554', None, None)
# (115, 6, 2, 115, 197, '82611', None, None)
# (116, 6, 2, 116, 174, '82614', None, None)
# (117, 6, 2, 117, 106, '82647', None, None)
# (118, 6, 2, 118, 74, '82650', None, None)
# (119, 6, 2, 119, 63, '82699', None, None)
# (120, 6, 2, 120, 205, '82704', None, None)
# (121, 6, 2, 121, 53, '82734', None, None)
# (122, 6, 2, 122, 22, '82744', None, None)
# (123, 6, 2, 123, 103, '82753', '20', None)
# (124, 6, 2, 124, 107, '82773', None, None)
# (125, 6, 2, 125, 128, '82773', None, None)
# (126, 6, 2, 126, 138, '82777', None, None)
# (127, 6, 2, 127, 203, '82804', None, None)
# (128, 6, 2, 128, 142, '82822', None, None)
# (129, 6, 2, 129, 7, '82845', None, None)
# (130, 6, 2, 130, 84, '82861', None, None)
# (131, 6, 2, 131, 45, '82891', None, None)
# (132, 6, 2, 132, 66, '82897', None, None)
# (133, 6, 2, 133, 206, '82909', '1', None)
# (134, 6, 2, 134, 112, '82912', None, None)
# (135, 6, 2, 135, 64, '82918', None, None)
# (136, 6, 2, 136, 65, '82972', None, None)
# (137, 6, 2, 137, 82, '82994', None, None)
# (138, 6, 2, 138, 186, '83017', None, None)
# (139, 6, 2, 139, 123, '83059', None, None)
# (140, 6, 2, 140, 3, '83065', None, None)
# (141, 6, 2, 141, 17, '83101', None, None)
# (142, 6, 2, 142, 202, '83149', '3', None)
# (143, 6, 2, 143, 124, '83194', None, None)
# (144, 6, 2, 144, 167, '83217', None, None)
# (145, 6, 2, 145, 98, '83249', None, None)
# (146, 6, 2, 146, 218, '83251', '2', None)
# (147, 6, 2, 147, 157, '83314', None, None)
# (148, 6, 2, 148, 102, '83342', None, None)
# (149, 6, 2, 149, 153, '83381', None, None)
# (150, 6, 2, 150, 213, '83396', None, None)
# (151, 6, 2, 151, 86, '83402', None, None)
# (152, 6, 2, 152, 73, '83420', None, None)
# (153, 6, 2, 153, 97, '83438', None, None)
# (154, 6, 2, 154, 185, '83442', None, None)
# (155, 6, 2, 155, 151, '83466', '4', None)
# (156, 6, 2, 156, 208, '83479', None, None)
# (157, 6, 2, 157, 201, '83479', None, None)
# (158, 6, 2, 158, 94, '83520', None, None)
# (159, 6, 2, 159, 15, '83536', None, None)
# (160, 6, 2, 160, 171, '83550', '4', None)
# (161, 6, 2, 161, 131, '83583', None, None)
# (162, 6, 2, 162, 173, '83600', None, None)
# (163, 6, 2, 163, 164, '83656', None, None)
# (164, 6, 2, 164, 135, '83669', None, None)
# (165, 6, 2, 165, 148, '83724', None, None)
# (166, 6, 2, 166, 163, '83735', None, None)
# (167, 6, 2, 167, 177, '83827', None, None)
# (168, 6, 2, 168, 137, '83891', None, None)
# (169, 6, 2, 169, 144, '83962', '4', None)
# (170, 6, 2, 170, 13, '84805', None, None)
# (171, 6, 1, 1, 91, '15223', '10', None)
# (172, 6, 1, 2, 26, '15224', '6', None)
# (173, 6, 1, 3, 78, '15226', '4', None)
# (174, 6, 1, 4, 101, '15226', None, None)
# (175, 6, 1, 5, 114, '15226', None, None)
# (176, 6, 1, 6, 61, '15226', None, None)
# (177, 6, 1, 7, 191, '15226', None, None)
# (178, 6, 1, 8, 111, '15226', None, None)
# (179, 6, 1, 9, 8, '15226', '2', None)
# (180, 6, 1, 10, 166, '15226', None, None)
# (181, 6, 1, 11, 81, '15226', None, None)
# (182, 6, 1, 12, 87, '15226', None, None)
# (183, 6, 1, 13, 71, '15226', None, None)
# (184, 6, 1, 14, 51, '15226', None, None)
# (185, 6, 1, 15, 121, '15226', None, None)
# (186, 6, 1, 16, 75, '15226', None, None)
# (187, 6, 1, 17, 88, '15229', None, None)
# (188, 6, 1, 18, 1, '15231', None, None)
# (189, 6, 1, 19, 11, '15234', None, None)
# (190, 6, 1, 20, 41, '15235', None, None)
# (191, 6, 1, 21, 105, '15235', None, None)
# (192, 6, 1, 22, 55, '15235', None, None)
# (193, 6, 1, 23, 141, '15235', None, None)
# (194, 6, 1, 24, 158, '15235', None, None)
# (195, 6, 1, 25, 161, '15235', None, None)
# (196, 6, 1, 26, 2, '15235', None, None)
# (197, 6, 1, 27, 204, '15235', None, None)
# (198, 6, 1, 28, 28, '15235', None, None)
# (199, 6, 1, 29, 136, '15235', None, None)
# (200, 6, 1, 30, 58, '15235', None, None)
# (201, 6, 1, 31, 104, '15235', None, None)
# (202, 6, 1, 32, 178, '15239', None, None)
# (203, 6, 1, 33, 21, '15254', None, None)
# (204, 6, 1, 34, 83, '15254', None, None)
# (205, 6, 1, 35, 16, '15254', None, None)
# (206, 6, 1, 36, 211, '15254', None, None)
# (207, 6, 1, 37, 216, '15264', None, None)
# (208, 6, 1, 38, 134, '15266', None, None)
# (209, 6, 1, 39, 152, '15266', None, None)
# (210, 6, 1, 40, 42, '15266', None, None)
# (211, 6, 1, 41, 125, '15268', None, None)
# (212, 6, 1, 42, 207, '15268', None, None)
# (213, 6, 1, 43, 188, '15268', None, None)
# (214, 6, 1, 44, 68, '15268', None, None)
# (215, 6, 1, 45, 36, '15276', None, None)
# (216, 6, 1, 46, 32, '15276', '-20', None)
# (217, 6, 1, 47, 183, '15281', None, None)
# (218, 6, 1, 48, 214, '15281', None, None)
# (219, 6, 1, 49, 43, '15287', None, None)
# (220, 6, 1, 50, 181, '15288', None, None)
# (221, 6, 1, 51, 67, '15299', None, None)
# (222, 6, 1, 52, 195, '15299', None, None)
# (223, 6, 1, 53, 155, '15306', None, None)
# (224, 6, 1, 54, 122, '15306', None, None)
# (225, 6, 1, 55, 192, '15306', None, None)
# (226, 6, 1, 56, 206, '15306', None, None)
# (227, 6, 1, 57, 162, '15341', None, None)
# (228, 6, 1, 58, 52, '15343', None, None)
# (229, 6, 1, 59, 54, '15343', None, None)
# (230, 6, 1, 60, 77, '15343', None, None)
# (231, 6, 1, 61, 126, '15357', None, None)
# (232, 6, 1, 62, 175, '15357', None, None)
# (233, 6, 1, 63, 76, '15360', None, None)
# (234, 6, 1, 64, 132, '15360', None, None)
# (235, 6, 1, 65, 44, '15360', None, None)
# (236, 6, 1, 66, 46, '15360', None, None)
# (237, 6, 1, 67, 154, '15360', None, None)
# (238, 6, 1, 68, 145, '15360', None, None)
# (239, 6, 1, 69, 6, '15360', None, None)
# (240, 6, 1, 70, 57, '15360', None, None)
# (241, 6, 1, 71, 72, '15360', None, None)
# (242, 6, 1, 72, 96, '15360', None, None)
# (243, 6, 1, 73, 93, '15360', None, None)
# (244, 6, 1, 74, 85, '15360', None, None)
# (245, 6, 1, 75, 12, '15360', None, None)
# (246, 6, 1, 76, 14, '15360', None, None)
# (247, 6, 1, 77, 24, '15360', None, None)
# (248, 6, 1, 78, 184, '15372', None, None)
# (249, 6, 1, 79, 27, '15372', None, None)
# (250, 6, 1, 80, 138, '15410', None, None)
# (251, 6, 1, 81, 212, '15410', None, None)
# (252, 6, 1, 82, 33, '15410', None, None)
# (253, 6, 1, 83, 215, '15410', None, None)
# (254, 6, 1, 84, 113, '15412', None, None)
# (255, 6, 1, 85, 35, '15412', None, None)
# (256, 6, 1, 86, 117, '15430', None, None)
# (257, 6, 1, 87, 182, '15431', None, None)
# (258, 6, 1, 88, 116, '15431', None, None)
# (259, 6, 1, 89, 187, '15441', None, None)
# (260, 6, 1, 90, 34, '15447', None, None)
# (261, 6, 1, 91, 37, '15447', None, None)
# (262, 6, 1, 92, 48, '15462', None, None)
# (263, 6, 1, 93, 133, '15462', None, None)
# (264, 6, 1, 94, 45, '15476', None, None)
# (265, 6, 1, 95, 165, '15497', None, None)
# (266, 6, 1, 96, 197, '15497', None, None)
# (267, 6, 1, 97, 63, '15497', None, None)
# (268, 6, 1, 98, 4, '15522', None, None)
# (269, 6, 1, 99, 176, '15522', '1', None)
# (270, 6, 1, 100, 22, '15561', None, None)
# (271, 6, 1, 101, 115, '15564', None, None)
# (272, 6, 1, 102, 38, '15564', None, None)
# (273, 6, 1, 103, 53, '15568', None, None)
# (274, 6, 1, 104, 142, '15568', None, None)
# (275, 6, 1, 105, 147, '15568', None, None)
# (276, 6, 1, 106, 62, '15569', '3', None)
# (277, 6, 1, 107, 18, '15569', None, None)
# (278, 6, 1, 108, 146, '15569', None, None)
# (279, 6, 1, 109, 156, '15578', None, None)
# (280, 6, 1, 110, 25, '15594', None, None)
# (281, 6, 1, 111, 5, '15601', None, None)
# (282, 6, 1, 112, 118, '15611', None, None)
# (283, 6, 1, 113, 203, '15626', None, None)
# (284, 6, 1, 114, 108, '15661', None, None)
# (285, 6, 1, 115, 3, '15673', None, None)
# (286, 6, 1, 116, 84, '15688', None, None)
# (287, 6, 1, 117, 56, '15728', None, None)
# (288, 6, 1, 118, 74, '15728', None, None)
# (289, 6, 1, 119, 17, '15728', None, None)
# (290, 6, 1, 120, 167, '15728', None, None)
# (291, 6, 1, 121, 186, '15769', None, None)
# (292, 6, 1, 122, 174, '15798', None, None)
# (293, 6, 1, 123, 218, '15800', None, None)
# (294, 6, 1, 124, 157, '15800', None, None)
# (295, 6, 1, 125, 202, '15800', None, None)
# (296, 6, 1, 126, 47, '15802', None, None)
# (297, 6, 1, 127, 193, '15836', None, None)
# (298, 6, 1, 128, 194, '15836', None, None)
# (299, 6, 1, 129, 64, '15836', None, None)
# (300, 6, 1, 130, 198, '15836', None, None)
# (301, 6, 1, 131, 217, '15874', None, None)
# (302, 6, 1, 132, 7, '15897', None, None)
# (303, 6, 1, 133, 137, '15897', None, None)
# (304, 6, 1, 134, 92, '15897', None, None)
# (305, 6, 1, 135, 205, '15897', None, None)
# (306, 6, 1, 136, 66, '15915', None, None)
# (307, 6, 1, 137, 208, '15928', None, None)
# (308, 6, 1, 138, 201, '15928', None, None)
# (309, 6, 1, 139, 73, '15928', None, None)
# (310, 6, 1, 140, 112, '15928', None, None)
# (311, 6, 1, 141, 97, '16093', None, None)
# (312, 6, 1, 142, 128, '16093', None, None)
# (313, 6, 1, 143, 213, '16093', None, None)
# (314, 6, 1, 144, 173, '16093', None, None)
# (315, 6, 1, 145, 177, '16093', None, None)
# (316, 6, 1, 146, 65, '16093', None, None)
# (317, 6, 1, 147, 86, '16093', None, None)
# (318, 6, 1, 148, 95, '16093', None, None)
# (319, 6, 1, 149, 102, '16093', None, None)
# (320, 6, 1, 150, 106, '16093', None, None)
# (321, 6, 1, 151, 131, '16093', None, None)
# (322, 6, 1, 152, 144, '16093', None, None)
# (323, 6, 1, 153, 148, '16093', None, None)
# (324, 6, 1, 154, 98, '16093', None, None)
# (325, 6, 1, 155, 107, '16093', None, None)
# (326, 6, 1, 156, 163, '16093', None, None)
# (327, 6, 1, 157, 171, '16093', None, None)
# (328, 6, 1, 158, 135, '16093', None, None)
# (329, 6, 1, 159, 82, '16093', None, None)
# (330, 6, 1, 160, 123, '16093', None, None)
# (331, 6, 1, 161, 103, '16093', None, None)
# (332, 6, 1, 162, 15, '16093', None, None)
# (333, 6, 1, 163, 168, '16093', None, None)
# (334, 6, 1, 164, 124, '16093', None, None)
# (335, 6, 1, 165, 151, '16093', None, None)
# (336, 6, 1, 166, 164, '16093', None, None)
# (337, 6, 1, 167, 153, '16093', None, None)
# (338, 6, 1, 168, 13, '16093', None, None)
# (339, 6, 1, 169, 94, '16093', None, None)
# (340, 6, 1, 170, 185, '16093', None, None)

# %%
def add_stage_3(filename)
    stage_3 = pd.read_csv(filename)

    stage_3['race_result_type_id'] = 1
    stage_3['stage_id'] = 3

    for index, row in stage_3.iterrows():
            if ':' in row['rider_time']:
                t = row['rider_time']
                t = t.split('.')[0]
                m,s = t.split(':')
                stage_3.loc[index, 'rider_time'] = int(datetime.timedelta(minutes=int(m),seconds=int(s)).total_seconds())

    engine = create_engine(f"mysql://{user}:{pwd}@localhost/letour_db")
    stage_3.to_sql(name='race_results',con=engine,if_exists='append', index=False)

# %%
add_stage_3("../sql/stage-3.csv")
